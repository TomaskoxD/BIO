# %%
import os
import argparse
import numpy as np
import torch
import torch.backends.cudnn as cudnn
import time
from progress.bar import Bar
import torchvision.transforms as transforms
from dataloader.EyeQ_loader import DatasetGenerator
from utils.trainer import train_step, validation_step, save_output
from utils.metric import compute_metric

import pandas as pd
from networks.densenet_mcf import dense121_mcs

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

np.random.seed(0)
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# Metric.py

# %%
import numpy as np
from sklearn.metrics import f1_score, confusion_matrix, roc_curve, roc_auc_score, accuracy_score

class MetricCalculator:
    def __init__(self, df, predictions, target_names):
        self.df = df
        self.predictions = predictions
        self.target_names = target_names
        self.n_class = len(target_names)
        self.argmaxPRED = np.argmax(predictions, axis=1)
        self.metrics = None

    def calculate_metrics(self):
        Accuracy_score = accuracy_score(self.df, self.argmaxPRED)
        metrics = {
            'class_name': self.target_names,
            'F1': [],
            'AUC': 0,
            'Accuracy': Accuracy_score,
            'Sensitivity': [],
            'Precision': [],
            'Specificity': [],
            'ROC_curve': {},
            'tp': [],
            'tn': [],
            'fp': [],
            'fn': [],
        }

        for i in range(self.n_class):
            tmp_label = self.df == i
            tmp_pred = self.argmaxPRED == i
            F1 = f1_score(tmp_label, tmp_pred)
            tn, fp, fn, tp = confusion_matrix(tmp_label, tmp_pred).ravel()
            outAUROC = roc_auc_score(tmp_label, self.predictions[:, i])

            metrics['F1'].append(F1)
            metrics['tp'].append(tp)
            metrics['tn'].append(tn)
            metrics['fp'].append(fp)
            metrics['fn'].append(fn)

            metrics['ROC_curve']['ROC_fpr_' + str(i)] = roc_curve(tmp_label, self.predictions[:, i])[0]
            metrics['ROC_curve']['ROC_tpr_' + str(i)] = roc_curve(tmp_label, self.predictions[:, i])[1]
            metrics['ROC_curve']['ROC_T_' + str(i)] = roc_curve(tmp_label, self.predictions[:, i])[2]
            metrics['ROC_curve']['AUC_' + str(i)] = outAUROC

            metrics['AUC'] += outAUROC
            metrics['Sensitivity'].append(tp / (tp + fn))
            metrics['Precision'].append(tp / (tp + fp))
            metrics['Specificity'].append(tn / (fp + tn))

        mPrecision = sum(metrics['tp']) / sum(metrics['tp'] + metrics['fp'])
        mRecall = sum(metrics['tp']) / sum(metrics['tp'] + metrics['fn'])

        metrics['micro-Precision'] = mPrecision
        metrics['micro-Sensitivity'] = mRecall
        metrics['micro-Specificity'] = sum(metrics['tn']) / sum(metrics['fp'] + metrics['tn'])
        metrics['micro-F1'] = 2 * mPrecision * mRecall / (mPrecision + mRecall)
        metrics['AUC'] /= self.n_class

        self.metrics = metrics

    def get_metrics(self):
        if self.metrics is None:
            self.calculate_metrics()
        return self.metrics

# %% [markdown]
# trainer.py Trainer class

# %%
class Trainer:
    def __init__(self, model, optimizer, criterion, loss_weights, epochs):
        self.model = model
        self.optimizer = optimizer
        self.criterion = criterion
        self.loss_weights = loss_weights
        self.epochs = epochs

    def train_step(self, train_loader, epoch):
        self.model.train()
        epoch_loss = 0.0
        iters_per_epoch = len(train_loader)
        print('\n\niters_per_epoch: ', iters_per_epoch, '\n\n')
        bar = Bar('Processing {} Epoch -> {} / {}'.format('train', epoch+1, self.epochs), max=iters_per_epoch)
        bar.check_tty = False

        for step, (imagesA, imagesB, imagesC, labels) in enumerate(train_loader):
            start_time = time.time()

            torch.set_grad_enabled(True)

            imagesA = imagesA.cuda()
            imagesB = imagesB.cuda()
            imagesC = imagesC.cuda()

            labels = labels.cuda()
            labels = labels.squeeze(1)

            out_A, out_B, out_C, out_F, combine = self.model(imagesA, imagesB, imagesC)

            loss_x = self.criterion(out_A, labels)
            loss_y = self.criterion(out_B, labels)
            loss_z = self.criterion(out_C, labels)
            loss_c = self.criterion(out_F, labels)
            loss_f = self.criterion(combine, labels)

            lossValue = (
                self.loss_weights[0] * loss_x +
                self.loss_weights[1] * loss_y +
                self.loss_weights[2] * loss_z +
                self.loss_weights[3] * loss_c +
                self.loss_weights[4] * loss_f
            )

            self.optimizer.zero_grad()
            lossValue.backward()
            self.optimizer.step()

            epoch_loss += lossValue.item()
            end_time = time.time()
            batch_time = end_time - start_time

            bar_str = '{} / {} | Time: {batch_time:.2f} mins | Loss: {loss:.4f} '
            bar.suffix = bar_str.format(
                step + 1, iters_per_epoch, batch_time=batch_time * (iters_per_epoch - step) / 60,
                loss=lossValue.item()
            )
            bar.next()

        epoch_loss = epoch_loss / iters_per_epoch
        bar.finish()
        return epoch_loss

# %% [markdown]
# trainer.py Validator class

# %%
class Validator:
    def __init__(self, model, criterion):
        self.model = model
        self.criterion = criterion

    def validate(self, val_loader):
        self.model.eval()
        epoch_loss = 0
        iters_per_epoch = len(val_loader)
        bar = Bar('Processing {}'.format('validation'), max=iters_per_epoch)

        for step, (imagesA, imagesB, imagesC, labels) in enumerate(val_loader):
            start_time = time.time()

            imagesA = imagesA.cuda()
            imagesB = imagesB.cuda()
            imagesC = imagesC.cuda()

            labels = labels.cuda()
            labels = labels.squeeze(1)

            _, _, _, _, outputs = self.model(imagesA, imagesB, imagesC)
            with torch.no_grad():
                loss = self.criterion(outputs, labels)
                epoch_loss += loss.item()

            end_time = time.time()

            batch_time = end_time - start_time
            bar_str = '{} / {} | Time: {batch_time:.2f} mins'
            bar.suffix = bar_str.format(step + 1, len(val_loader), batch_time=batch_time * (iters_per_epoch - step) / 60)
            bar.next()

        epoch_loss = epoch_loss / iters_per_epoch
        bar.finish()
        return epoch_loss

# %% [markdown]
# trainer.py Saver class ... maybe move to another file

# %%
class Saver:
    def __init__(self, label_list):
        self.label_list = label_list
        self.n_class = len(label_list)

    def save(self, label_test_file, dataPRED, save_file):
        datanpPRED = np.squeeze(dataPRED.cpu().numpy())
        df_tmp = pd.read_csv(label_test_file)
        image_names = df_tmp["image"].tolist()

        result = {self.label_list[i]: datanpPRED[:, i] for i in range(self.n_class)}
        result['image_name'] = image_names
        out_df = pd.DataFrame(result)

        name_order = ['image_name'] + self.label_list
        out_df.to_csv(save_file, columns=name_order)

# %%
# train_images_dir = data_root + '/train'
n_classes = 3
pre_model='DenseNet121_v3_v1'
lr=0.01
batch_size=4

label_train_file = '../data/Label_EyeQ_test.csv' # swapped
# test_images_dir = data_root + '/test'
label_test_file = '../data/Label_EyeQ_train.csv' # swapped


save_file_name = 'DenseNet121_v3_v1_mine.csv'

best_metric = np.inf
best_iter = 0
# options
cudnn.benchmark = True

model = dense121_mcs(n_classes)

if pre_model is not None:
    loaded_model = torch.load(os.path.join('../',pre_model + '.tar'))
    model.load_state_dict(loaded_model['state_dict'])

model.to(device)

criterion = torch.nn.BCELoss(reduction='mean')
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

print('Total params: %.2fM' % (sum(p.numel() for p in model.parameters()) / 1000000.0))
# Out:
# /home/tomas/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/tomas/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Total params: 28.86M

# %%
transform_list1 = transforms.Compose([
        transforms.Resize(256),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(degrees=(-180, +180)),
    ])

transformList2 = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

transform_list_val1 = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
    ])

# %%
test_images_dir ='../../preprocess/train_preprocessed'
train_images_dir = '../../preprocess/train_preprocessed'

data_test = DatasetGenerator(data_dir=test_images_dir, list_file=label_test_file, transform1=transform_list_val1,
                             transform2=transformList2, n_class=n_classes, set_name='test')

# %%
data_test.image_names
# Out:
# ['../../preprocess/train_preprocessed/10009_left.png',
#  '../../preprocess/train_preprocessed/10009_right.png',
#  '../../preprocess/train_preprocessed/10014_left.png',
#  '../../preprocess/train_preprocessed/10014_right.png',
#  '../../preprocess/train_preprocessed/10015_left.png',
#  '../../preprocess/train_preprocessed/10015_right.png',
#  '../../preprocess/train_preprocessed/10017_left.png',
#  '../../preprocess/train_preprocessed/1002_left.png',
#  '../../preprocess/train_preprocessed/10022_right.png',
#  '../../preprocess/train_preprocessed/10028_left.png',
#  '../../preprocess/train_preprocessed/10029_left.png',
#  '../../preprocess/train_preprocessed/10030_left.png',
#  '../../preprocess/train_preprocessed/10030_right.png',
#  '../../preprocess/train_preprocessed/10031_left.png',
#  '../../preprocess/train_preprocessed/10031_right.png',
#  '../../preprocess/train_preprocessed/10043_left.png',
#  '../../preprocess/train_preprocessed/10043_right.png',
#  '../../preprocess/train_preprocessed/10058_left.png',
#  '../../preprocess/train_preprocessed/10061_left.png',
#  '../../preprocess/train_preprocessed/10061_right.png',
#  '../../preprocess/train_preprocessed/10069_right.png',
#  '../../preprocess/train_preprocessed/1008_left.png',
#  '../../preprocess/train_preprocessed/10085_left.png',
#  '../../preprocess/train_preprocessed/10085_right.png',
#  '../../preprocess/train_preprocessed/10095_left.png',
#  '../../preprocess/train_preprocessed/10100_left.png',
#  '../../preprocess/train_preprocessed/10100_right.png',
#  '../../preprocess/train_preprocessed/10112_left.png',
#  '../../preprocess/train_preprocessed/10116_left.png',
#  '../../preprocess/train_preprocessed/10116_right.png',
#  '../../preprocess/train_preprocessed/10124_left.png',
#  '../../preprocess/train_preprocessed/10124_right.png',
#  '../../preprocess/train_preprocessed/10125_left.png',
#  '../../preprocess/train_preprocessed/10125_right.png',
#  '../../preprocess/train_preprocessed/10129_left.png',
#  '../../preprocess/train_preprocessed/10130_left.png',
#  '../../preprocess/train_preprocessed/10131_left.png',
#  '../../preprocess/train_preprocessed/10131_right.png',
#  '../../preprocess/train_preprocessed/10134_left.png',
#  '../../preprocess/train_preprocessed/10141_left.png',
#  '../../preprocess/train_preprocessed/10147_right.png',
#  '../../preprocess/train_preprocessed/10150_left.png',
#  '../../preprocess/train_preprocessed/10150_right.png',
#  '../../preprocess/train_preprocessed/10159_left.png',
#  '../../preprocess/train_preprocessed/10159_right.png',
#  '../../preprocess/train_preprocessed/10160_left.png',
#  '../../preprocess/train_preprocessed/10160_right.png',
#  '../../preprocess/train_preprocessed/10161_right.png',
#  '../../preprocess/train_preprocessed/10166_right.png',
#  '../../preprocess/train_preprocessed/10169_left.png',
#  '../../preprocess/train_preprocessed/10177_left.png',
#  '../../preprocess/train_preprocessed/10177_right.png',
#  '../../preprocess/train_preprocessed/10181_right.png',
#  '../../preprocess/train_preprocessed/10182_left.png',
#  '../../preprocess/train_preprocessed/10182_right.png',
#  '../../preprocess/train_preprocessed/10183_left.png',
#  '../../preprocess/train_preprocessed/10183_right.png',
#  '../../preprocess/train_preprocessed/10190_left.png',
#  '../../preprocess/train_preprocessed/10190_right.png',
#  '../../preprocess/train_preprocessed/10199_left.png',
#  '../../preprocess/train_preprocessed/102_left.png',
#  '../../preprocess/train_preprocessed/1020_left.png',
#  '../../preprocess/train_preprocessed/1020_right.png',
#  '../../preprocess/train_preprocessed/10206_left.png',
#  '../../preprocess/train_preprocessed/10206_right.png',
#  '../../preprocess/train_preprocessed/1021_left.png',
#  '../../preprocess/train_preprocessed/1021_right.png',
#  '../../preprocess/train_preprocessed/10210_left.png',
#  '../../preprocess/train_preprocessed/10210_right.png',
#  '../../preprocess/train_preprocessed/10212_right.png',
#  '../../preprocess/train_preprocessed/10218_left.png',
#  '../../preprocess/train_preprocessed/10218_right.png',
#  '../../preprocess/train_preprocessed/10223_left.png',
#  '../../preprocess/train_preprocessed/10223_right.png',
#  '../../preprocess/train_preprocessed/10226_right.png',
#  '../../preprocess/train_preprocessed/10230_left.png',
#  '../../preprocess/train_preprocessed/10230_right.png',
#  '../../preprocess/train_preprocessed/10234_left.png',
#  '../../preprocess/train_preprocessed/10234_right.png',
#  '../../preprocess/train_preprocessed/10239_right.png',
#  '../../preprocess/train_preprocessed/10241_right.png',
#  '../../preprocess/train_preprocessed/10243_right.png',
#  '../../preprocess/train_preprocessed/10244_right.png',
#  '../../preprocess/train_preprocessed/10255_right.png',
#  '../../preprocess/train_preprocessed/10257_left.png',
#  '../../preprocess/train_preprocessed/10257_right.png',
#  '../../preprocess/train_preprocessed/10276_left.png',
#  '../../preprocess/train_preprocessed/10276_right.png',
#  '../../preprocess/train_preprocessed/10279_left.png',
#  '../../preprocess/train_preprocessed/10284_left.png',
#  '../../preprocess/train_preprocessed/10284_right.png',
#  '../../preprocess/train_preprocessed/10288_left.png',
#  '../../preprocess/train_preprocessed/1029_left.png',
#  '../../preprocess/train_preprocessed/10295_left.png',
#  '../../preprocess/train_preprocessed/10297_right.png',
#  '../../preprocess/train_preprocessed/10310_left.png',
#  '../../preprocess/train_preprocessed/10312_left.png',
#  '../../preprocess/train_preprocessed/10312_right.png',
#  '../../preprocess/train_preprocessed/10319_left.png',
#  '../../preprocess/train_preprocessed/10319_right.png',
#  '../../preprocess/train_preprocessed/1032_left.png',
#  '../../preprocess/train_preprocessed/1032_right.png',
#  '../../preprocess/train_preprocessed/10321_right.png',
#  '../../preprocess/train_preprocessed/10325_left.png',
#  '../../preprocess/train_preprocessed/10325_right.png',
#  '../../preprocess/train_preprocessed/10328_left.png',
#  '../../preprocess/train_preprocessed/10333_left.png',
#  '../../preprocess/train_preprocessed/10333_right.png',
#  '../../preprocess/train_preprocessed/10334_left.png',
#  '../../preprocess/train_preprocessed/10337_left.png',
#  '../../preprocess/train_preprocessed/10337_right.png',
#  '../../preprocess/train_preprocessed/1034_left.png',
#  '../../preprocess/train_preprocessed/1034_right.png',
#  '../../preprocess/train_preprocessed/10340_left.png',
#  '../../preprocess/train_preprocessed/10340_right.png',
#  '../../preprocess/train_preprocessed/10343_left.png',
#  '../../preprocess/train_preprocessed/1035_left.png',
#  '../../preprocess/train_preprocessed/1035_right.png',
#  '../../preprocess/train_preprocessed/10353_right.png',
#  '../../preprocess/train_preprocessed/1036_left.png',
#  '../../preprocess/train_preprocessed/1036_right.png',
#  '../../preprocess/train_preprocessed/10368_right.png',
#  '../../preprocess/train_preprocessed/10369_left.png',
#  '../../preprocess/train_preprocessed/10369_right.png',
#  '../../preprocess/train_preprocessed/10384_right.png',
#  '../../preprocess/train_preprocessed/10388_left.png',
#  '../../preprocess/train_preprocessed/10389_left.png',
#  '../../preprocess/train_preprocessed/10389_right.png',
#  '../../preprocess/train_preprocessed/10391_left.png',
#  '../../preprocess/train_preprocessed/10391_right.png',
#  '../../preprocess/train_preprocessed/1040_right.png',
#  '../../preprocess/train_preprocessed/10400_left.png',
#  '../../preprocess/train_preprocessed/10400_right.png',
#  '../../preprocess/train_preprocessed/10401_left.png',
#  '../../preprocess/train_preprocessed/10407_right.png',
#  '../../preprocess/train_preprocessed/10408_left.png',
#  '../../preprocess/train_preprocessed/10409_left.png',
#  '../../preprocess/train_preprocessed/10421_left.png',
#  '../../preprocess/train_preprocessed/10421_right.png',
#  '../../preprocess/train_preprocessed/10427_left.png',
#  '../../preprocess/train_preprocessed/10427_right.png',
#  '../../preprocess/train_preprocessed/10429_right.png',
#  '../../preprocess/train_preprocessed/10437_left.png',
#  '../../preprocess/train_preprocessed/10437_right.png',
#  '../../preprocess/train_preprocessed/10440_left.png',
#  '../../preprocess/train_preprocessed/10444_left.png',
#  '../../preprocess/train_preprocessed/10448_right.png',
#  '../../preprocess/train_preprocessed/10452_left.png',
#  '../../preprocess/train_preprocessed/10452_right.png',
#  '../../preprocess/train_preprocessed/10454_left.png',
#  '../../preprocess/train_preprocessed/10457_left.png',
#  '../../preprocess/train_preprocessed/10457_right.png',
#  '../../preprocess/train_preprocessed/10464_left.png',
#  '../../preprocess/train_preprocessed/10468_left.png',
#  '../../preprocess/train_preprocessed/10468_right.png',
#  '../../preprocess/train_preprocessed/10481_left.png',
#  '../../preprocess/train_preprocessed/10489_left.png',
#  '../../preprocess/train_preprocessed/1050_left.png',
#  '../../preprocess/train_preprocessed/10501_left.png',
#  '../../preprocess/train_preprocessed/10501_right.png',
#  '../../preprocess/train_preprocessed/10502_right.png',
#  '../../preprocess/train_preprocessed/10503_left.png',
#  '../../preprocess/train_preprocessed/1051_left.png',
#  '../../preprocess/train_preprocessed/1051_right.png',
#  '../../preprocess/train_preprocessed/10511_left.png',
#  '../../preprocess/train_preprocessed/10511_right.png',
#  '../../preprocess/train_preprocessed/1052_left.png',
#  '../../preprocess/train_preprocessed/10523_left.png',
#  '../../preprocess/train_preprocessed/10523_right.png',
#  '../../preprocess/train_preprocessed/10534_left.png',
#  '../../preprocess/train_preprocessed/10541_left.png',
#  '../../preprocess/train_preprocessed/10548_right.png',
#  '../../preprocess/train_preprocessed/1055_left.png',
#  '../../preprocess/train_preprocessed/1055_right.png',
#  '../../preprocess/train_preprocessed/10553_left.png',
#  '../../preprocess/train_preprocessed/10553_right.png',
#  '../../preprocess/train_preprocessed/10558_left.png',
#  '../../preprocess/train_preprocessed/10558_right.png',
#  '../../preprocess/train_preprocessed/10560_left.png',
#  '../../preprocess/train_preprocessed/10560_right.png',
#  '../../preprocess/train_preprocessed/10562_left.png',
#  '../../preprocess/train_preprocessed/10562_right.png',
#  '../../preprocess/train_preprocessed/10563_right.png',
#  '../../preprocess/train_preprocessed/10567_left.png',
#  '../../preprocess/train_preprocessed/10568_left.png',
#  '../../preprocess/train_preprocessed/10569_left.png',
#  '../../preprocess/train_preprocessed/10585_left.png',
#  '../../preprocess/train_preprocessed/10585_right.png',
#  '../../preprocess/train_preprocessed/10592_right.png',
#  '../../preprocess/train_preprocessed/10594_right.png',
#  '../../preprocess/train_preprocessed/10605_right.png',
#  '../../preprocess/train_preprocessed/10606_left.png',
#  '../../preprocess/train_preprocessed/10606_right.png',
#  '../../preprocess/train_preprocessed/1061_right.png',
#  '../../preprocess/train_preprocessed/10610_right.png',
#  '../../preprocess/train_preprocessed/10612_right.png',
#  '../../preprocess/train_preprocessed/10614_right.png',
#  '../../preprocess/train_preprocessed/10616_right.png',
#  '../../preprocess/train_preprocessed/10623_left.png',
#  '../../preprocess/train_preprocessed/10634_left.png',
#  '../../preprocess/train_preprocessed/10636_left.png',
#  '../../preprocess/train_preprocessed/10636_right.png',
#  '../../preprocess/train_preprocessed/10640_left.png',
#  '../../preprocess/train_preprocessed/10640_right.png',
#  '../../preprocess/train_preprocessed/10643_left.png',
#  '../../preprocess/train_preprocessed/10644_left.png',
#  '../../preprocess/train_preprocessed/10645_left.png',
#  '../../preprocess/train_preprocessed/10647_left.png',
#  '../../preprocess/train_preprocessed/10647_right.png',
#  '../../preprocess/train_preprocessed/10650_right.png',
#  '../../preprocess/train_preprocessed/10657_left.png',
#  '../../preprocess/train_preprocessed/10657_right.png',
#  '../../preprocess/train_preprocessed/10658_right.png',
#  '../../preprocess/train_preprocessed/10660_left.png',
#  '../../preprocess/train_preprocessed/10660_right.png',
#  '../../preprocess/train_preprocessed/10672_left.png',
#  '../../preprocess/train_preprocessed/10672_right.png',
#  '../../preprocess/train_preprocessed/10675_left.png',
#  '../../preprocess/train_preprocessed/10694_left.png',
#  '../../preprocess/train_preprocessed/10694_right.png',
#  '../../preprocess/train_preprocessed/10698_right.png',
#  '../../preprocess/train_preprocessed/10710_left.png',
#  '../../preprocess/train_preprocessed/10710_right.png',
#  '../../preprocess/train_preprocessed/10722_left.png',
#  '../../preprocess/train_preprocessed/10727_left.png',
#  '../../preprocess/train_preprocessed/10727_right.png',
#  '../../preprocess/train_preprocessed/10729_left.png',
#  '../../preprocess/train_preprocessed/1073_left.png',
#  '../../preprocess/train_preprocessed/10732_left.png',
#  '../../preprocess/train_preprocessed/10734_left.png',
#  '../../preprocess/train_preprocessed/10734_right.png',
#  '../../preprocess/train_preprocessed/10743_left.png',
#  '../../preprocess/train_preprocessed/10743_right.png',
#  '../../preprocess/train_preprocessed/10745_right.png',
#  '../../preprocess/train_preprocessed/10751_left.png',
#  '../../preprocess/train_preprocessed/10752_right.png',
#  '../../preprocess/train_preprocessed/10758_left.png',
#  '../../preprocess/train_preprocessed/10758_right.png',
#  '../../preprocess/train_preprocessed/1076_left.png',
#  '../../preprocess/train_preprocessed/10771_right.png',
#  '../../preprocess/train_preprocessed/10781_left.png',
#  '../../preprocess/train_preprocessed/10781_right.png',
#  '../../preprocess/train_preprocessed/10782_left.png',
#  '../../preprocess/train_preprocessed/10790_left.png',
#  '../../preprocess/train_preprocessed/10790_right.png',
#  '../../preprocess/train_preprocessed/10794_right.png',
#  '../../preprocess/train_preprocessed/10810_left.png',
#  '../../preprocess/train_preprocessed/10811_left.png',
#  '../../preprocess/train_preprocessed/10814_left.png',
#  '../../preprocess/train_preprocessed/10814_right.png',
#  '../../preprocess/train_preprocessed/10831_right.png',
#  '../../preprocess/train_preprocessed/10832_right.png',
#  '../../preprocess/train_preprocessed/10833_left.png',
#  '../../preprocess/train_preprocessed/10833_right.png',
#  '../../preprocess/train_preprocessed/10835_left.png',
#  '../../preprocess/train_preprocessed/10842_left.png',
#  '../../preprocess/train_preprocessed/10844_right.png',
#  '../../preprocess/train_preprocessed/10853_right.png',
#  '../../preprocess/train_preprocessed/10854_right.png',
#  '../../preprocess/train_preprocessed/10861_right.png',
#  '../../preprocess/train_preprocessed/10864_right.png',
#  '../../preprocess/train_preprocessed/10874_left.png',
#  '../../preprocess/train_preprocessed/10874_right.png',
#  '../../preprocess/train_preprocessed/1088_left.png',
#  '../../preprocess/train_preprocessed/1088_right.png',
#  '../../preprocess/train_preprocessed/10886_left.png',
#  '../../preprocess/train_preprocessed/10891_left.png',
#  '../../preprocess/train_preprocessed/10891_right.png',
#  '../../preprocess/train_preprocessed/10907_left.png',
#  '../../preprocess/train_preprocessed/10907_right.png',
#  '../../preprocess/train_preprocessed/10913_left.png',
#  '../../preprocess/train_preprocessed/10913_right.png',
#  '../../preprocess/train_preprocessed/10915_left.png',
#  '../../preprocess/train_preprocessed/10915_right.png',
#  '../../preprocess/train_preprocessed/10916_right.png',
#  '../../preprocess/train_preprocessed/10919_left.png',
#  '../../preprocess/train_preprocessed/10919_right.png',
#  '../../preprocess/train_preprocessed/1092_left.png',
#  '../../preprocess/train_preprocessed/10923_right.png',
#  '../../preprocess/train_preprocessed/10924_left.png',
#  '../../preprocess/train_preprocessed/10924_right.png',
#  '../../preprocess/train_preprocessed/10934_left.png',
#  '../../preprocess/train_preprocessed/10940_left.png',
#  '../../preprocess/train_preprocessed/10940_right.png',
#  '../../preprocess/train_preprocessed/10942_right.png',
#  '../../preprocess/train_preprocessed/10947_left.png',
#  '../../preprocess/train_preprocessed/10947_right.png',
#  '../../preprocess/train_preprocessed/10952_left.png',
#  '../../preprocess/train_preprocessed/10952_right.png',
#  '../../preprocess/train_preprocessed/10954_left.png',
#  '../../preprocess/train_preprocessed/1096_right.png',
#  '../../preprocess/train_preprocessed/10960_left.png',
#  '../../preprocess/train_preprocessed/10961_left.png',
#  '../../preprocess/train_preprocessed/10961_right.png',
#  '../../preprocess/train_preprocessed/10962_left.png',
#  '../../preprocess/train_preprocessed/10963_left.png',
#  '../../preprocess/train_preprocessed/10966_left.png',
#  '../../preprocess/train_preprocessed/10966_right.png',
#  '../../preprocess/train_preprocessed/10969_left.png',
#  '../../preprocess/train_preprocessed/10969_right.png',
#  '../../preprocess/train_preprocessed/10974_right.png',
#  '../../preprocess/train_preprocessed/10975_left.png',
#  '../../preprocess/train_preprocessed/10975_right.png',
#  '../../preprocess/train_preprocessed/10976_left.png',
#  '../../preprocess/train_preprocessed/1098_left.png',
#  '../../preprocess/train_preprocessed/10987_right.png',
#  '../../preprocess/train_preprocessed/10994_left.png',
#  '../../preprocess/train_preprocessed/10996_left.png',
#  '../../preprocess/train_preprocessed/10996_right.png',
#  '../../preprocess/train_preprocessed/1100_left.png',
#  '../../preprocess/train_preprocessed/1100_right.png',
#  '../../preprocess/train_preprocessed/11007_right.png',
#  '../../preprocess/train_preprocessed/1102_left.png',
#  '../../preprocess/train_preprocessed/11026_left.png',
#  '../../preprocess/train_preprocessed/11032_left.png',
#  '../../preprocess/train_preprocessed/11035_left.png',
#  '../../preprocess/train_preprocessed/11035_right.png',
#  '../../preprocess/train_preprocessed/11037_right.png',
#  '../../preprocess/train_preprocessed/11041_left.png',
#  '../../preprocess/train_preprocessed/11041_right.png',
#  '../../preprocess/train_preprocessed/11048_left.png',
#  '../../preprocess/train_preprocessed/11050_left.png',
#  '../../preprocess/train_preprocessed/11053_right.png',
#  '../../preprocess/train_preprocessed/11056_right.png',
#  '../../preprocess/train_preprocessed/11058_left.png',
#  '../../preprocess/train_preprocessed/11058_right.png',
#  '../../preprocess/train_preprocessed/11067_right.png',
#  '../../preprocess/train_preprocessed/11079_left.png',
#  '../../preprocess/train_preprocessed/11080_left.png',
#  '../../preprocess/train_preprocessed/11080_right.png',
#  '../../preprocess/train_preprocessed/11087_left.png',
#  '../../preprocess/train_preprocessed/11087_right.png',
#  '../../preprocess/train_preprocessed/11089_left.png',
#  '../../preprocess/train_preprocessed/11089_right.png',
#  '../../preprocess/train_preprocessed/11091_left.png',
#  '../../preprocess/train_preprocessed/11091_right.png',
#  '../../preprocess/train_preprocessed/11098_left.png',
#  '../../preprocess/train_preprocessed/11099_left.png',
#  '../../preprocess/train_preprocessed/111_left.png',
#  '../../preprocess/train_preprocessed/11101_left.png',
#  '../../preprocess/train_preprocessed/11106_left.png',
#  '../../preprocess/train_preprocessed/11106_right.png',
#  '../../preprocess/train_preprocessed/11117_left.png',
#  '../../preprocess/train_preprocessed/11117_right.png',
#  '../../preprocess/train_preprocessed/11120_right.png',
#  '../../preprocess/train_preprocessed/11123_right.png',
#  '../../preprocess/train_preprocessed/11124_left.png',
#  '../../preprocess/train_preprocessed/11129_right.png',
#  '../../preprocess/train_preprocessed/1113_left.png',
#  '../../preprocess/train_preprocessed/1113_right.png',
#  '../../preprocess/train_preprocessed/11143_left.png',
#  '../../preprocess/train_preprocessed/11143_right.png',
#  '../../preprocess/train_preprocessed/11149_right.png',
#  '../../preprocess/train_preprocessed/11155_right.png',
#  '../../preprocess/train_preprocessed/11157_left.png',
#  '../../preprocess/train_preprocessed/11157_right.png',
#  '../../preprocess/train_preprocessed/11158_left.png',
#  '../../preprocess/train_preprocessed/11158_right.png',
#  '../../preprocess/train_preprocessed/1116_right.png',
#  '../../preprocess/train_preprocessed/11163_right.png',
#  '../../preprocess/train_preprocessed/11165_right.png',
#  '../../preprocess/train_preprocessed/11176_left.png',
#  '../../preprocess/train_preprocessed/11176_right.png',
#  '../../preprocess/train_preprocessed/11180_left.png',
#  '../../preprocess/train_preprocessed/11180_right.png',
#  '../../preprocess/train_preprocessed/11181_left.png',
#  '../../preprocess/train_preprocessed/11182_left.png',
#  '../../preprocess/train_preprocessed/11182_right.png',
#  '../../preprocess/train_preprocessed/11183_left.png',
#  '../../preprocess/train_preprocessed/11183_right.png',
#  '../../preprocess/train_preprocessed/1119_left.png',
#  '../../preprocess/train_preprocessed/11192_left.png',
#  '../../preprocess/train_preprocessed/11196_left.png',
#  '../../preprocess/train_preprocessed/11198_right.png',
#  '../../preprocess/train_preprocessed/11203_left.png',
#  '../../preprocess/train_preprocessed/11204_left.png',
#  '../../preprocess/train_preprocessed/11206_left.png',
#  '../../preprocess/train_preprocessed/11206_right.png',
#  '../../preprocess/train_preprocessed/11211_right.png',
#  '../../preprocess/train_preprocessed/11222_right.png',
#  '../../preprocess/train_preprocessed/11228_left.png',
#  '../../preprocess/train_preprocessed/1123_right.png',
#  '../../preprocess/train_preprocessed/11244_left.png',
#  '../../preprocess/train_preprocessed/11246_left.png',
#  '../../preprocess/train_preprocessed/11246_right.png',
#  '../../preprocess/train_preprocessed/11247_right.png',
#  '../../preprocess/train_preprocessed/11265_left.png',
#  '../../preprocess/train_preprocessed/11265_right.png',
#  '../../preprocess/train_preprocessed/11268_left.png',
#  '../../preprocess/train_preprocessed/11270_left.png',
#  '../../preprocess/train_preprocessed/11270_right.png',
#  '../../preprocess/train_preprocessed/11271_right.png',
#  '../../preprocess/train_preprocessed/11273_right.png',
#  '../../preprocess/train_preprocessed/11289_left.png',
#  '../../preprocess/train_preprocessed/11292_left.png',
#  '../../preprocess/train_preprocessed/11292_right.png',
#  '../../preprocess/train_preprocessed/11293_right.png',
#  '../../preprocess/train_preprocessed/11294_left.png',
#  '../../preprocess/train_preprocessed/11294_right.png',
#  '../../preprocess/train_preprocessed/11301_left.png',
#  '../../preprocess/train_preprocessed/11304_left.png',
#  '../../preprocess/train_preprocessed/11305_right.png',
#  '../../preprocess/train_preprocessed/11314_left.png',
#  '../../preprocess/train_preprocessed/11314_right.png',
#  '../../preprocess/train_preprocessed/11325_right.png',
#  '../../preprocess/train_preprocessed/11326_right.png',
#  '../../preprocess/train_preprocessed/1133_left.png',
#  '../../preprocess/train_preprocessed/11348_right.png',
#  '../../preprocess/train_preprocessed/1136_left.png',
#  '../../preprocess/train_preprocessed/1136_right.png',
#  '../../preprocess/train_preprocessed/11362_left.png',
#  '../../preprocess/train_preprocessed/11362_right.png',
#  '../../preprocess/train_preprocessed/11365_left.png',
#  '../../preprocess/train_preprocessed/11365_right.png',
#  '../../preprocess/train_preprocessed/11371_left.png',
#  '../../preprocess/train_preprocessed/11384_right.png',
#  '../../preprocess/train_preprocessed/11385_left.png',
#  '../../preprocess/train_preprocessed/11385_right.png',
#  '../../preprocess/train_preprocessed/1139_left.png',
#  '../../preprocess/train_preprocessed/1139_right.png',
#  '../../preprocess/train_preprocessed/11393_right.png',
#  '../../preprocess/train_preprocessed/11397_right.png',
#  '../../preprocess/train_preprocessed/1140_left.png',
#  '../../preprocess/train_preprocessed/1140_right.png',
#  '../../preprocess/train_preprocessed/1142_left.png',
#  '../../preprocess/train_preprocessed/11420_left.png',
#  '../../preprocess/train_preprocessed/11420_right.png',
#  '../../preprocess/train_preprocessed/11427_left.png',
#  '../../preprocess/train_preprocessed/11427_right.png',
#  '../../preprocess/train_preprocessed/11431_left.png',
#  '../../preprocess/train_preprocessed/1144_left.png',
#  '../../preprocess/train_preprocessed/1144_right.png',
#  '../../preprocess/train_preprocessed/11448_left.png',
#  '../../preprocess/train_preprocessed/11448_right.png',
#  '../../preprocess/train_preprocessed/1145_right.png',
#  '../../preprocess/train_preprocessed/11455_left.png',
#  '../../preprocess/train_preprocessed/11455_right.png',
#  '../../preprocess/train_preprocessed/11464_left.png',
#  '../../preprocess/train_preprocessed/11471_left.png',
#  '../../preprocess/train_preprocessed/11471_right.png',
#  '../../preprocess/train_preprocessed/11474_left.png',
#  '../../preprocess/train_preprocessed/11482_left.png',
#  '../../preprocess/train_preprocessed/11482_right.png',
#  '../../preprocess/train_preprocessed/11485_left.png',
#  '../../preprocess/train_preprocessed/11487_left.png',
#  '../../preprocess/train_preprocessed/11487_right.png',
#  '../../preprocess/train_preprocessed/11490_left.png',
#  '../../preprocess/train_preprocessed/11490_right.png',
#  '../../preprocess/train_preprocessed/11492_right.png',
#  '../../preprocess/train_preprocessed/11494_left.png',
#  '../../preprocess/train_preprocessed/11494_right.png',
#  '../../preprocess/train_preprocessed/11495_left.png',
#  '../../preprocess/train_preprocessed/11495_right.png',
#  '../../preprocess/train_preprocessed/115_right.png',
#  '../../preprocess/train_preprocessed/11503_left.png',
#  '../../preprocess/train_preprocessed/11503_right.png',
#  '../../preprocess/train_preprocessed/11504_left.png',
#  '../../preprocess/train_preprocessed/11504_right.png',
#  '../../preprocess/train_preprocessed/11519_right.png',
#  '../../preprocess/train_preprocessed/11527_right.png',
#  '../../preprocess/train_preprocessed/11534_left.png',
#  '../../preprocess/train_preprocessed/11534_right.png',
#  '../../preprocess/train_preprocessed/11539_right.png',
#  '../../preprocess/train_preprocessed/11545_left.png',
#  '../../preprocess/train_preprocessed/11545_right.png',
#  '../../preprocess/train_preprocessed/11546_left.png',
#  '../../preprocess/train_preprocessed/11546_right.png',
#  '../../preprocess/train_preprocessed/11547_left.png',
#  '../../preprocess/train_preprocessed/11547_right.png',
#  '../../preprocess/train_preprocessed/11550_left.png',
#  '../../preprocess/train_preprocessed/11550_right.png',
#  '../../preprocess/train_preprocessed/11553_right.png',
#  '../../preprocess/train_preprocessed/11555_left.png',
#  '../../preprocess/train_preprocessed/11574_left.png',
#  '../../preprocess/train_preprocessed/11574_right.png',
#  '../../preprocess/train_preprocessed/11579_left.png',
#  '../../preprocess/train_preprocessed/11584_left.png',
#  '../../preprocess/train_preprocessed/11594_left.png',
#  '../../preprocess/train_preprocessed/11598_left.png',
#  '../../preprocess/train_preprocessed/11598_right.png',
#  '../../preprocess/train_preprocessed/1161_left.png',
#  '../../preprocess/train_preprocessed/1161_right.png',
#  '../../preprocess/train_preprocessed/11616_left.png',
#  '../../preprocess/train_preprocessed/11616_right.png',
#  '../../preprocess/train_preprocessed/11618_left.png',
#  '../../preprocess/train_preprocessed/11623_right.png',
#  '../../preprocess/train_preprocessed/11624_left.png',
#  '../../preprocess/train_preprocessed/11624_right.png',
#  '../../preprocess/train_preprocessed/11625_left.png',
#  '../../preprocess/train_preprocessed/11625_right.png',
#  '../../preprocess/train_preprocessed/11638_left.png',
#  '../../preprocess/train_preprocessed/11638_right.png',
#  '../../preprocess/train_preprocessed/11639_left.png',
#  '../../preprocess/train_preprocessed/11639_right.png',
#  '../../preprocess/train_preprocessed/11642_left.png',
#  '../../preprocess/train_preprocessed/11642_right.png',
#  '../../preprocess/train_preprocessed/11645_left.png',
#  '../../preprocess/train_preprocessed/11645_right.png',
#  '../../preprocess/train_preprocessed/11646_left.png',
#  '../../preprocess/train_preprocessed/11649_left.png',
#  '../../preprocess/train_preprocessed/11652_left.png',
#  '../../preprocess/train_preprocessed/11652_right.png',
#  '../../preprocess/train_preprocessed/11655_left.png',
#  '../../preprocess/train_preprocessed/11655_right.png',
#  '../../preprocess/train_preprocessed/11661_left.png',
#  '../../preprocess/train_preprocessed/11665_left.png',
#  '../../preprocess/train_preprocessed/11665_right.png',
#  '../../preprocess/train_preprocessed/1167_left.png',
#  '../../preprocess/train_preprocessed/11677_right.png',
#  '../../preprocess/train_preprocessed/11684_right.png',
#  '../../preprocess/train_preprocessed/11697_left.png',
#  '../../preprocess/train_preprocessed/11697_right.png',
#  '../../preprocess/train_preprocessed/11698_right.png',
#  '../../preprocess/train_preprocessed/11703_right.png',
#  '../../preprocess/train_preprocessed/11707_right.png',
#  '../../preprocess/train_preprocessed/11717_left.png',
#  '../../preprocess/train_preprocessed/11717_right.png',
#  '../../preprocess/train_preprocessed/11719_left.png',
#  '../../preprocess/train_preprocessed/11724_left.png',
#  '../../preprocess/train_preprocessed/11724_right.png',
#  '../../preprocess/train_preprocessed/11734_left.png',
#  '../../preprocess/train_preprocessed/11736_left.png',
#  '../../preprocess/train_preprocessed/11736_right.png',
#  '../../preprocess/train_preprocessed/11738_left.png',
#  '../../preprocess/train_preprocessed/11738_right.png',
#  '../../preprocess/train_preprocessed/11744_left.png',
#  '../../preprocess/train_preprocessed/11744_right.png',
#  '../../preprocess/train_preprocessed/11750_left.png',
#  '../../preprocess/train_preprocessed/11759_right.png',
#  '../../preprocess/train_preprocessed/11770_left.png',
#  '../../preprocess/train_preprocessed/11770_right.png',
#  '../../preprocess/train_preprocessed/11781_right.png',
#  '../../preprocess/train_preprocessed/11802_left.png',
#  '../../preprocess/train_preprocessed/11805_left.png',
#  '../../preprocess/train_preprocessed/11805_right.png',
#  '../../preprocess/train_preprocessed/11811_right.png',
#  '../../preprocess/train_preprocessed/11816_left.png',
#  '../../preprocess/train_preprocessed/11816_right.png',
#  '../../preprocess/train_preprocessed/11818_left.png',
#  '../../preprocess/train_preprocessed/11818_right.png',
#  '../../preprocess/train_preprocessed/1182_left.png',
#  '../../preprocess/train_preprocessed/11826_left.png',
#  '../../preprocess/train_preprocessed/11828_right.png',
#  '../../preprocess/train_preprocessed/11849_right.png',
#  '../../preprocess/train_preprocessed/11854_right.png',
#  '../../preprocess/train_preprocessed/11855_left.png',
#  '../../preprocess/train_preprocessed/11858_left.png',
#  '../../preprocess/train_preprocessed/11858_right.png',
#  '../../preprocess/train_preprocessed/11866_right.png',
#  '../../preprocess/train_preprocessed/1188_left.png',
#  '../../preprocess/train_preprocessed/1188_right.png',
#  '../../preprocess/train_preprocessed/11890_left.png',
#  '../../preprocess/train_preprocessed/11890_right.png',
#  '../../preprocess/train_preprocessed/11894_left.png',
#  '../../preprocess/train_preprocessed/11894_right.png',
#  '../../preprocess/train_preprocessed/11896_left.png',
#  '../../preprocess/train_preprocessed/11896_right.png',
#  '../../preprocess/train_preprocessed/11904_left.png',
#  '../../preprocess/train_preprocessed/11904_right.png',
#  '../../preprocess/train_preprocessed/11909_left.png',
#  '../../preprocess/train_preprocessed/11909_right.png',
#  '../../preprocess/train_preprocessed/11914_right.png',
#  '../../preprocess/train_preprocessed/11915_left.png',
#  '../../preprocess/train_preprocessed/11915_right.png',
#  '../../preprocess/train_preprocessed/11916_left.png',
#  '../../preprocess/train_preprocessed/1192_right.png',
#  '../../preprocess/train_preprocessed/11923_right.png',
#  '../../preprocess/train_preprocessed/11926_left.png',
#  '../../preprocess/train_preprocessed/11926_right.png',
#  '../../preprocess/train_preprocessed/11929_left.png',
#  '../../preprocess/train_preprocessed/11937_left.png',
#  '../../preprocess/train_preprocessed/11937_right.png',
#  '../../preprocess/train_preprocessed/11940_left.png',
#  '../../preprocess/train_preprocessed/11942_left.png',
#  '../../preprocess/train_preprocessed/11946_left.png',
#  '../../preprocess/train_preprocessed/11946_right.png',
#  '../../preprocess/train_preprocessed/11949_left.png',
#  '../../preprocess/train_preprocessed/11949_right.png',
#  '../../preprocess/train_preprocessed/11952_right.png',
#  '../../preprocess/train_preprocessed/11957_left.png',
#  '../../preprocess/train_preprocessed/11957_right.png',
#  '../../preprocess/train_preprocessed/1196_right.png',
#  '../../preprocess/train_preprocessed/11966_right.png',
#  '../../preprocess/train_preprocessed/11970_left.png',
#  '../../preprocess/train_preprocessed/11971_left.png',
#  '../../preprocess/train_preprocessed/11974_left.png',
#  '../../preprocess/train_preprocessed/11974_right.png',
#  '../../preprocess/train_preprocessed/11982_right.png',
#  '../../preprocess/train_preprocessed/11989_right.png',
#  '../../preprocess/train_preprocessed/1199_left.png',
#  '../../preprocess/train_preprocessed/1199_right.png',
#  '../../preprocess/train_preprocessed/11990_left.png',
#  '../../preprocess/train_preprocessed/11997_left.png',
#  '../../preprocess/train_preprocessed/11997_right.png',
#  '../../preprocess/train_preprocessed/12000_left.png',
#  '../../preprocess/train_preprocessed/12000_right.png',
#  '../../preprocess/train_preprocessed/12005_right.png',
#  '../../preprocess/train_preprocessed/12010_left.png',
#  '../../preprocess/train_preprocessed/12010_right.png',
#  '../../preprocess/train_preprocessed/12014_right.png',
#  '../../preprocess/train_preprocessed/12018_left.png',
#  '../../preprocess/train_preprocessed/1202_left.png',
#  '../../preprocess/train_preprocessed/1202_right.png',
#  '../../preprocess/train_preprocessed/12027_left.png',
#  '../../preprocess/train_preprocessed/12027_right.png',
#  '../../preprocess/train_preprocessed/12040_left.png',
#  '../../preprocess/train_preprocessed/1206_left.png',
#  '../../preprocess/train_preprocessed/1206_right.png',
#  '../../preprocess/train_preprocessed/12072_left.png',
#  '../../preprocess/train_preprocessed/12074_right.png',
#  '../../preprocess/train_preprocessed/12075_left.png',
#  '../../preprocess/train_preprocessed/12075_right.png',
#  '../../preprocess/train_preprocessed/12079_left.png',
#  '../../preprocess/train_preprocessed/12079_right.png',
#  '../../preprocess/train_preprocessed/12092_left.png',
#  '../../preprocess/train_preprocessed/12092_right.png',
#  '../../preprocess/train_preprocessed/12098_left.png',
#  '../../preprocess/train_preprocessed/12101_left.png',
#  '../../preprocess/train_preprocessed/12101_right.png',
#  '../../preprocess/train_preprocessed/12104_left.png',
#  '../../preprocess/train_preprocessed/12105_left.png',
#  '../../preprocess/train_preprocessed/12106_left.png',
#  '../../preprocess/train_preprocessed/12106_right.png',
#  '../../preprocess/train_preprocessed/1211_left.png',
#  '../../preprocess/train_preprocessed/1211_right.png',
#  '../../preprocess/train_preprocessed/12124_left.png',
#  '../../preprocess/train_preprocessed/12124_right.png',
#  '../../preprocess/train_preprocessed/12126_left.png',
#  '../../preprocess/train_preprocessed/12126_right.png',
#  '../../preprocess/train_preprocessed/12129_left.png',
#  '../../preprocess/train_preprocessed/12133_left.png',
#  '../../preprocess/train_preprocessed/12133_right.png',
#  '../../preprocess/train_preprocessed/12139_left.png',
#  '../../preprocess/train_preprocessed/12139_right.png',
#  '../../preprocess/train_preprocessed/12141_left.png',
#  '../../preprocess/train_preprocessed/12144_right.png',
#  '../../preprocess/train_preprocessed/12146_left.png',
#  '../../preprocess/train_preprocessed/12146_right.png',
#  '../../preprocess/train_preprocessed/12148_left.png',
#  '../../preprocess/train_preprocessed/12149_right.png',
#  '../../preprocess/train_preprocessed/12154_right.png',
#  '../../preprocess/train_preprocessed/12155_left.png',
#  '../../preprocess/train_preprocessed/12155_right.png',
#  '../../preprocess/train_preprocessed/12156_left.png',
#  '../../preprocess/train_preprocessed/12156_right.png',
#  '../../preprocess/train_preprocessed/12157_left.png',
#  '../../preprocess/train_preprocessed/12159_right.png',
#  '../../preprocess/train_preprocessed/12168_left.png',
#  '../../preprocess/train_preprocessed/12168_right.png',
#  '../../preprocess/train_preprocessed/12175_right.png',
#  '../../preprocess/train_preprocessed/12187_left.png',
#  '../../preprocess/train_preprocessed/12187_right.png',
#  '../../preprocess/train_preprocessed/12193_right.png',
#  '../../preprocess/train_preprocessed/122_left.png',
#  '../../preprocess/train_preprocessed/12205_left.png',
#  '../../preprocess/train_preprocessed/12205_right.png',
#  '../../preprocess/train_preprocessed/12208_left.png',
#  '../../preprocess/train_preprocessed/12208_right.png',
#  '../../preprocess/train_preprocessed/12210_left.png',
#  '../../preprocess/train_preprocessed/12210_right.png',
#  '../../preprocess/train_preprocessed/12213_left.png',
#  '../../preprocess/train_preprocessed/12214_right.png',
#  '../../preprocess/train_preprocessed/1222_left.png',
#  '../../preprocess/train_preprocessed/1222_right.png',
#  '../../preprocess/train_preprocessed/12227_left.png',
#  '../../preprocess/train_preprocessed/12231_right.png',
#  '../../preprocess/train_preprocessed/12233_left.png',
#  '../../preprocess/train_preprocessed/12233_right.png',
#  '../../preprocess/train_preprocessed/12241_left.png',
#  '../../preprocess/train_preprocessed/12241_right.png',
#  '../../preprocess/train_preprocessed/12247_left.png',
#  '../../preprocess/train_preprocessed/12247_right.png',
#  '../../preprocess/train_preprocessed/12255_left.png',
#  '../../preprocess/train_preprocessed/12255_right.png',
#  '../../preprocess/train_preprocessed/12256_left.png',
#  '../../preprocess/train_preprocessed/12256_right.png',
#  '../../preprocess/train_preprocessed/12258_left.png',
#  '../../preprocess/train_preprocessed/12264_right.png',
#  '../../preprocess/train_preprocessed/12278_left.png',
#  '../../preprocess/train_preprocessed/1228_left.png',
#  '../../preprocess/train_preprocessed/12286_left.png',
#  '../../preprocess/train_preprocessed/12286_right.png',
#  '../../preprocess/train_preprocessed/12292_left.png',
#  '../../preprocess/train_preprocessed/12295_left.png',
#  '../../preprocess/train_preprocessed/12295_right.png',
#  '../../preprocess/train_preprocessed/12301_left.png',
#  '../../preprocess/train_preprocessed/12301_right.png',
#  '../../preprocess/train_preprocessed/12303_left.png',
#  '../../preprocess/train_preprocessed/12303_right.png',
#  '../../preprocess/train_preprocessed/12305_left.png',
#  '../../preprocess/train_preprocessed/12305_right.png',
#  '../../preprocess/train_preprocessed/12306_left.png',
#  '../../preprocess/train_preprocessed/12307_left.png',
#  '../../preprocess/train_preprocessed/12307_right.png',
#  '../../preprocess/train_preprocessed/12311_left.png',
#  '../../preprocess/train_preprocessed/12311_right.png',
#  '../../preprocess/train_preprocessed/12313_left.png',
#  '../../preprocess/train_preprocessed/12313_right.png',
#  '../../preprocess/train_preprocessed/12316_left.png',
#  '../../preprocess/train_preprocessed/12316_right.png',
#  '../../preprocess/train_preprocessed/12320_left.png',
#  '../../preprocess/train_preprocessed/12321_right.png',
#  '../../preprocess/train_preprocessed/12325_left.png',
#  '../../preprocess/train_preprocessed/12326_left.png',
#  '../../preprocess/train_preprocessed/12326_right.png',
#  '../../preprocess/train_preprocessed/12329_left.png',
#  '../../preprocess/train_preprocessed/12329_right.png',
#  '../../preprocess/train_preprocessed/12353_left.png',
#  '../../preprocess/train_preprocessed/12356_left.png',
#  '../../preprocess/train_preprocessed/12378_right.png',
#  '../../preprocess/train_preprocessed/12382_right.png',
#  '../../preprocess/train_preprocessed/12396_left.png',
#  '../../preprocess/train_preprocessed/12396_right.png',
#  '../../preprocess/train_preprocessed/12397_left.png',
#  '../../preprocess/train_preprocessed/12397_right.png',
#  '../../preprocess/train_preprocessed/12399_left.png',
#  '../../preprocess/train_preprocessed/12399_right.png',
#  '../../preprocess/train_preprocessed/1240_right.png',
#  '../../preprocess/train_preprocessed/12410_left.png',
#  '../../preprocess/train_preprocessed/12411_right.png',
#  '../../preprocess/train_preprocessed/12417_left.png',
#  '../../preprocess/train_preprocessed/12417_right.png',
#  '../../preprocess/train_preprocessed/12419_right.png',
#  '../../preprocess/train_preprocessed/1242_left.png',
#  '../../preprocess/train_preprocessed/12425_right.png',
#  '../../preprocess/train_preprocessed/12429_right.png',
#  '../../preprocess/train_preprocessed/12433_left.png',
#  '../../preprocess/train_preprocessed/12433_right.png',
#  '../../preprocess/train_preprocessed/12441_right.png',
#  '../../preprocess/train_preprocessed/12444_right.png',
#  '../../preprocess/train_preprocessed/12464_right.png',
#  '../../preprocess/train_preprocessed/12468_right.png',
#  '../../preprocess/train_preprocessed/12471_right.png',
#  '../../preprocess/train_preprocessed/12476_left.png',
#  '../../preprocess/train_preprocessed/12476_right.png',
#  '../../preprocess/train_preprocessed/12478_right.png',
#  '../../preprocess/train_preprocessed/12480_left.png',
#  '../../preprocess/train_preprocessed/12480_right.png',
#  '../../preprocess/train_preprocessed/12484_left.png',
#  '../../preprocess/train_preprocessed/12484_right.png',
#  '../../preprocess/train_preprocessed/12488_left.png',
#  '../../preprocess/train_preprocessed/12490_left.png',
#  '../../preprocess/train_preprocessed/12491_left.png',
#  '../../preprocess/train_preprocessed/12491_right.png',
#  '../../preprocess/train_preprocessed/12496_right.png',
#  '../../preprocess/train_preprocessed/125_right.png',
#  '../../preprocess/train_preprocessed/12506_left.png',
#  '../../preprocess/train_preprocessed/12506_right.png',
#  '../../preprocess/train_preprocessed/12511_left.png',
#  '../../preprocess/train_preprocessed/12511_right.png',
#  '../../preprocess/train_preprocessed/12515_left.png',
#  '../../preprocess/train_preprocessed/12515_right.png',
#  '../../preprocess/train_preprocessed/12519_left.png',
#  '../../preprocess/train_preprocessed/12519_right.png',
#  '../../preprocess/train_preprocessed/12521_left.png',
#  '../../preprocess/train_preprocessed/12521_right.png',
#  '../../preprocess/train_preprocessed/12523_left.png',
#  '../../preprocess/train_preprocessed/12525_right.png',
#  '../../preprocess/train_preprocessed/12527_left.png',
#  '../../preprocess/train_preprocessed/12527_right.png',
#  '../../preprocess/train_preprocessed/12533_left.png',
#  '../../preprocess/train_preprocessed/12536_left.png',
#  '../../preprocess/train_preprocessed/12536_right.png',
#  '../../preprocess/train_preprocessed/12546_right.png',
#  '../../preprocess/train_preprocessed/12547_left.png',
#  '../../preprocess/train_preprocessed/12547_right.png',
#  '../../preprocess/train_preprocessed/12561_right.png',
#  '../../preprocess/train_preprocessed/12563_left.png',
#  '../../preprocess/train_preprocessed/12565_left.png',
#  '../../preprocess/train_preprocessed/12565_right.png',
#  '../../preprocess/train_preprocessed/12567_left.png',
#  '../../preprocess/train_preprocessed/12573_left.png',
#  '../../preprocess/train_preprocessed/12575_right.png',
#  '../../preprocess/train_preprocessed/12586_left.png',
#  '../../preprocess/train_preprocessed/12586_right.png',
#  '../../preprocess/train_preprocessed/12590_left.png',
#  '../../preprocess/train_preprocessed/12590_right.png',
#  '../../preprocess/train_preprocessed/12591_right.png',
#  '../../preprocess/train_preprocessed/12596_left.png',
#  '../../preprocess/train_preprocessed/12597_left.png',
#  '../../preprocess/train_preprocessed/1260_left.png',
#  '../../preprocess/train_preprocessed/1260_right.png',
#  '../../preprocess/train_preprocessed/12602_left.png',
#  '../../preprocess/train_preprocessed/12612_left.png',
#  '../../preprocess/train_preprocessed/12612_right.png',
#  '../../preprocess/train_preprocessed/12614_left.png',
#  '../../preprocess/train_preprocessed/12614_right.png',
#  '../../preprocess/train_preprocessed/12620_left.png',
#  '../../preprocess/train_preprocessed/12626_left.png',
#  '../../preprocess/train_preprocessed/12626_right.png',
#  '../../preprocess/train_preprocessed/12629_right.png',
#  '../../preprocess/train_preprocessed/12630_left.png',
#  '../../preprocess/train_preprocessed/12630_right.png',
#  '../../preprocess/train_preprocessed/12631_left.png',
#  '../../preprocess/train_preprocessed/12631_right.png',
#  '../../preprocess/train_preprocessed/12639_left.png',
#  '../../preprocess/train_preprocessed/12639_right.png',
#  '../../preprocess/train_preprocessed/12642_left.png',
#  '../../preprocess/train_preprocessed/12642_right.png',
#  '../../preprocess/train_preprocessed/12646_right.png',
#  '../../preprocess/train_preprocessed/12651_right.png',
#  '../../preprocess/train_preprocessed/12652_left.png',
#  '../../preprocess/train_preprocessed/12654_right.png',
#  '../../preprocess/train_preprocessed/1266_left.png',
#  '../../preprocess/train_preprocessed/12660_left.png',
#  '../../preprocess/train_preprocessed/12662_left.png',
#  '../../preprocess/train_preprocessed/12666_left.png',
#  '../../preprocess/train_preprocessed/12667_right.png',
#  '../../preprocess/train_preprocessed/12675_left.png',
#  '../../preprocess/train_preprocessed/12675_right.png',
#  '../../preprocess/train_preprocessed/12676_left.png',
#  '../../preprocess/train_preprocessed/12678_left.png',
#  '../../preprocess/train_preprocessed/12678_right.png',
#  '../../preprocess/train_preprocessed/12681_right.png',
#  '../../preprocess/train_preprocessed/12687_right.png',
#  '../../preprocess/train_preprocessed/12699_left.png',
#  '../../preprocess/train_preprocessed/12699_right.png',
#  '../../preprocess/train_preprocessed/12700_left.png',
#  '../../preprocess/train_preprocessed/12700_right.png',
#  '../../preprocess/train_preprocessed/12708_left.png',
#  '../../preprocess/train_preprocessed/12708_right.png',
#  '../../preprocess/train_preprocessed/12714_left.png',
#  '../../preprocess/train_preprocessed/12714_right.png',
#  '../../preprocess/train_preprocessed/12715_left.png',
#  '../../preprocess/train_preprocessed/12715_right.png',
#  '../../preprocess/train_preprocessed/12716_right.png',
#  '../../preprocess/train_preprocessed/12721_left.png',
#  '../../preprocess/train_preprocessed/12721_right.png',
#  '../../preprocess/train_preprocessed/12725_left.png',
#  '../../preprocess/train_preprocessed/12725_right.png',
#  '../../preprocess/train_preprocessed/12734_right.png',
#  '../../preprocess/train_preprocessed/12735_left.png',
#  '../../preprocess/train_preprocessed/12735_right.png',
#  '../../preprocess/train_preprocessed/12739_left.png',
#  '../../preprocess/train_preprocessed/12741_left.png',
#  '../../preprocess/train_preprocessed/12741_right.png',
#  '../../preprocess/train_preprocessed/12743_left.png',
#  '../../preprocess/train_preprocessed/12743_right.png',
#  '../../preprocess/train_preprocessed/12745_left.png',
#  '../../preprocess/train_preprocessed/1275_left.png',
#  '../../preprocess/train_preprocessed/1275_right.png',
#  '../../preprocess/train_preprocessed/12769_left.png',
#  '../../preprocess/train_preprocessed/1277_left.png',
#  '../../preprocess/train_preprocessed/1277_right.png',
#  '../../preprocess/train_preprocessed/12779_left.png',
#  '../../preprocess/train_preprocessed/12779_right.png',
#  '../../preprocess/train_preprocessed/12783_left.png',
#  '../../preprocess/train_preprocessed/12787_right.png',
#  '../../preprocess/train_preprocessed/12790_right.png',
#  '../../preprocess/train_preprocessed/12799_left.png',
#  '../../preprocess/train_preprocessed/12805_right.png',
#  '../../preprocess/train_preprocessed/12817_left.png',
#  '../../preprocess/train_preprocessed/12817_right.png',
#  '../../preprocess/train_preprocessed/12822_right.png',
#  '../../preprocess/train_preprocessed/12835_left.png',
#  '../../preprocess/train_preprocessed/12839_left.png',
#  '../../preprocess/train_preprocessed/12839_right.png',
#  '../../preprocess/train_preprocessed/12842_left.png',
#  '../../preprocess/train_preprocessed/12844_left.png',
#  '../../preprocess/train_preprocessed/12844_right.png',
#  '../../preprocess/train_preprocessed/1285_left.png',
#  '../../preprocess/train_preprocessed/1285_right.png',
#  '../../preprocess/train_preprocessed/12861_left.png',
#  '../../preprocess/train_preprocessed/12863_left.png',
#  '../../preprocess/train_preprocessed/12863_right.png',
#  '../../preprocess/train_preprocessed/12865_left.png',
#  '../../preprocess/train_preprocessed/12866_right.png',
#  '../../preprocess/train_preprocessed/12867_right.png',
#  '../../preprocess/train_preprocessed/12870_left.png',
#  '../../preprocess/train_preprocessed/12878_left.png',
#  '../../preprocess/train_preprocessed/12878_right.png',
#  '../../preprocess/train_preprocessed/1289_left.png',
#  '../../preprocess/train_preprocessed/129_left.png',
#  '../../preprocess/train_preprocessed/129_right.png',
#  '../../preprocess/train_preprocessed/12910_left.png',
#  '../../preprocess/train_preprocessed/12910_right.png',
#  '../../preprocess/train_preprocessed/12912_left.png',
#  '../../preprocess/train_preprocessed/12912_right.png',
#  '../../preprocess/train_preprocessed/12917_right.png',
#  '../../preprocess/train_preprocessed/12918_left.png',
#  '../../preprocess/train_preprocessed/12918_right.png',
#  '../../preprocess/train_preprocessed/12920_left.png',
#  '../../preprocess/train_preprocessed/12920_right.png',
#  '../../preprocess/train_preprocessed/12923_right.png',
#  '../../preprocess/train_preprocessed/12924_right.png',
#  '../../preprocess/train_preprocessed/12929_right.png',
#  '../../preprocess/train_preprocessed/12933_right.png',
#  '../../preprocess/train_preprocessed/12937_left.png',
#  '../../preprocess/train_preprocessed/1294_left.png',
#  '../../preprocess/train_preprocessed/1294_right.png',
#  '../../preprocess/train_preprocessed/12941_left.png',
#  '../../preprocess/train_preprocessed/12941_right.png',
#  '../../preprocess/train_preprocessed/12944_right.png',
#  '../../preprocess/train_preprocessed/12945_left.png',
#  '../../preprocess/train_preprocessed/12947_left.png',
#  '../../preprocess/train_preprocessed/12947_right.png',
#  '../../preprocess/train_preprocessed/12948_left.png',
#  '../../preprocess/train_preprocessed/12950_left.png',
#  '../../preprocess/train_preprocessed/12950_right.png',
#  '../../preprocess/train_preprocessed/12951_left.png',
#  '../../preprocess/train_preprocessed/12951_right.png',
#  '../../preprocess/train_preprocessed/12954_left.png',
#  '../../preprocess/train_preprocessed/12955_left.png',
#  '../../preprocess/train_preprocessed/12958_left.png',
#  '../../preprocess/train_preprocessed/12965_left.png',
#  '../../preprocess/train_preprocessed/12965_right.png',
#  '../../preprocess/train_preprocessed/12971_left.png',
#  '../../preprocess/train_preprocessed/12971_right.png',
#  '../../preprocess/train_preprocessed/12975_left.png',
#  '../../preprocess/train_preprocessed/12977_left.png',
#  '../../preprocess/train_preprocessed/12979_right.png',
#  '../../preprocess/train_preprocessed/12985_left.png',
#  '../../preprocess/train_preprocessed/12988_left.png',
#  '../../preprocess/train_preprocessed/12990_left.png',
#  '../../preprocess/train_preprocessed/12992_left.png',
#  '../../preprocess/train_preprocessed/12995_right.png',
#  '../../preprocess/train_preprocessed/13_left.png',
#  '../../preprocess/train_preprocessed/13_right.png',
#  '../../preprocess/train_preprocessed/13006_left.png',
#  '../../preprocess/train_preprocessed/13013_left.png',
#  '../../preprocess/train_preprocessed/13013_right.png',
#  '../../preprocess/train_preprocessed/13014_left.png',
#  '../../preprocess/train_preprocessed/13014_right.png',
#  '../../preprocess/train_preprocessed/13015_left.png',
#  '../../preprocess/train_preprocessed/13017_left.png',
#  '../../preprocess/train_preprocessed/13017_right.png',
#  '../../preprocess/train_preprocessed/13019_left.png',
#  '../../preprocess/train_preprocessed/13019_right.png',
#  '../../preprocess/train_preprocessed/1302_left.png',
#  '../../preprocess/train_preprocessed/13022_left.png',
#  '../../preprocess/train_preprocessed/13022_right.png',
#  '../../preprocess/train_preprocessed/13033_right.png',
#  '../../preprocess/train_preprocessed/13036_left.png',
#  '../../preprocess/train_preprocessed/13036_right.png',
#  '../../preprocess/train_preprocessed/13041_right.png',
#  '../../preprocess/train_preprocessed/13042_left.png',
#  '../../preprocess/train_preprocessed/13042_right.png',
#  '../../preprocess/train_preprocessed/13043_right.png',
#  '../../preprocess/train_preprocessed/13051_left.png',
#  '../../preprocess/train_preprocessed/13051_right.png',
#  '../../preprocess/train_preprocessed/13054_left.png',
#  '../../preprocess/train_preprocessed/13064_left.png',
#  '../../preprocess/train_preprocessed/13064_right.png',
#  '../../preprocess/train_preprocessed/13065_left.png',
#  '../../preprocess/train_preprocessed/13065_right.png',
#  '../../preprocess/train_preprocessed/13066_left.png',
#  '../../preprocess/train_preprocessed/13066_right.png',
#  '../../preprocess/train_preprocessed/13069_left.png',
#  '../../preprocess/train_preprocessed/13069_right.png',
#  '../../preprocess/train_preprocessed/1307_left.png',
#  '../../preprocess/train_preprocessed/13078_left.png',
#  '../../preprocess/train_preprocessed/13078_right.png',
#  '../../preprocess/train_preprocessed/13089_right.png',
#  '../../preprocess/train_preprocessed/13094_left.png',
#  '../../preprocess/train_preprocessed/13094_right.png',
#  '../../preprocess/train_preprocessed/13099_left.png',
#  '../../preprocess/train_preprocessed/13106_right.png',
#  '../../preprocess/train_preprocessed/13112_left.png',
#  '../../preprocess/train_preprocessed/13112_right.png',
#  '../../preprocess/train_preprocessed/13116_right.png',
#  '../../preprocess/train_preprocessed/13125_right.png',
#  '../../preprocess/train_preprocessed/13126_left.png',
#  '../../preprocess/train_preprocessed/13126_right.png',
#  '../../preprocess/train_preprocessed/13128_left.png',
#  '../../preprocess/train_preprocessed/13128_right.png',
#  '../../preprocess/train_preprocessed/1313_left.png',
#  '../../preprocess/train_preprocessed/13130_right.png',
#  '../../preprocess/train_preprocessed/13136_right.png',
#  '../../preprocess/train_preprocessed/13137_right.png',
#  '../../preprocess/train_preprocessed/13150_left.png',
#  '../../preprocess/train_preprocessed/13150_right.png',
#  '../../preprocess/train_preprocessed/13156_left.png',
#  '../../preprocess/train_preprocessed/13156_right.png',
#  '../../preprocess/train_preprocessed/13158_right.png',
#  '../../preprocess/train_preprocessed/13160_right.png',
#  '../../preprocess/train_preprocessed/13169_right.png',
#  '../../preprocess/train_preprocessed/13170_left.png',
#  '../../preprocess/train_preprocessed/13173_left.png',
#  '../../preprocess/train_preprocessed/13176_left.png',
#  '../../preprocess/train_preprocessed/13176_right.png',
#  '../../preprocess/train_preprocessed/13178_left.png',
#  '../../preprocess/train_preprocessed/13178_right.png',
#  '../../preprocess/train_preprocessed/13180_left.png',
#  '../../preprocess/train_preprocessed/13180_right.png',
#  '../../preprocess/train_preprocessed/13184_left.png',
#  '../../preprocess/train_preprocessed/13190_left.png',
#  '../../preprocess/train_preprocessed/13192_left.png',
#  '../../preprocess/train_preprocessed/13196_left.png',
#  '../../preprocess/train_preprocessed/13210_left.png',
#  '../../preprocess/train_preprocessed/13210_right.png',
#  '../../preprocess/train_preprocessed/13211_right.png',
#  '../../preprocess/train_preprocessed/13214_right.png',
#  '../../preprocess/train_preprocessed/1322_left.png',
#  '../../preprocess/train_preprocessed/1322_right.png',
#  '../../preprocess/train_preprocessed/13220_right.png',
#  '../../preprocess/train_preprocessed/13229_left.png',
#  '../../preprocess/train_preprocessed/13229_right.png',
#  '../../preprocess/train_preprocessed/13230_left.png',
#  '../../preprocess/train_preprocessed/13237_left.png',
#  '../../preprocess/train_preprocessed/13237_right.png',
#  ...]

# %%
test_loader = torch.utils.data.DataLoader(dataset=data_test, batch_size=batch_size,
                                          shuffle=False, num_workers=4, pin_memory=True)

# %%
print('Test loader length: ', len(test_loader.dataset.image_names))
print('Test loader length: ', len(test_loader.dataset.labels))
# Out:
# Test loader length:  12543
# Test loader length:  12543

# %%
outPRED_mcs = torch.FloatTensor().cuda()
model.eval()
iters_per_epoch = len(test_loader)
bar = Bar('Processing {}'.format('inference'), max=len(test_loader))
bar.check_tty = False
for epochID, (imagesA, imagesB, imagesC) in enumerate(test_loader):
    imagesA = imagesA.cuda()
    imagesB = imagesB.cuda()
    imagesC = imagesC.cuda()

    begin_time = time.time()
    _, _, _, _, result_mcs = model(imagesA, imagesB, imagesC)
    outPRED_mcs = torch.cat((outPRED_mcs, result_mcs.data), 0)
    batch_time = time.time() - begin_time
    bar.suffix = '{} / {} | Time: {batch_time:.4f}'.format(epochID + 1, len(test_loader),
                                                           batch_time=batch_time * (iters_per_epoch - epochID) / 60)
    bar.next()
bar.finish()

# # save result into excel:
# save_output(label_test_file, outPRED_mcs, args, save_file=save_file_name)
# Out:
# Processing inference |                                | 8 / 3136 | Time: 3.209958
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2136/399444960.py in <module>
#      10
#      11     begin_time = time.time()
# ---> 12     _, _, _, _, result_mcs = model(imagesA, imagesB, imagesC)
#      13     outPRED_mcs = torch.cat((outPRED_mcs, result_mcs.data), 0)
#      14     batch_time = time.time() - begin_time
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/Nextcloud/SYNC/BIO/EyeQ/MCF_Net/networks/densenet_mcf.py in forward(self, x, y, z)
#      64     def forward(self, x, y, z):
#      65         x1 = self.featureA(x)
# ---> 66         y1 = self.featureB(y)
#      67         z1 = self.featureC(z)
#      68         x2 = self.classA(x)
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/Nextcloud/SYNC/BIO/EyeQ/MCF_Net/networks/densenet_mcf.py in forward(self, x)
#      22
#      23     def forward(self, x):
# ---> 24         x = self.densenet121(x)
#      25         return x
#      26
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/.local/lib/python3.10/site-packages/torchvision/models/densenet.py in forward(self, x)
#     211
#     212     def forward(self, x: Tensor) -> Tensor:
# --> 213         features = self.features(x)
#     214         out = F.relu(features, inplace=True)
#     215         out = F.adaptive_avg_pool2d(out, (1, 1))
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py in forward(self, input)
#     213     def forward(self, input):
#     214         for module in self:
# --> 215             input = module(input)
#     216         return input
#     217
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/.local/lib/python3.10/site-packages/torchvision/models/densenet.py in forward(self, init_features)
#     120         features = [init_features]
#     121         for name, layer in self.items():
# --> 122             new_features = layer(features)
#     123             features.append(new_features)
#     124         return torch.cat(features, 1)
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/.local/lib/python3.10/site-packages/torchvision/models/densenet.py in forward(self, input)
#      86             bottleneck_output = self.call_checkpoint_bottleneck(prev_features)
#      87         else:
# ---> 88             bottleneck_output = self.bn_function(prev_features)
#      89
#      90         new_features = self.conv2(self.relu2(self.norm2(bottleneck_output)))
#
# ~/.local/lib/python3.10/site-packages/torchvision/models/densenet.py in bn_function(self, inputs)
#      47     def bn_function(self, inputs: List[Tensor]) -> Tensor:
#      48         concated_features = torch.cat(inputs, 1)
# ---> 49         bottleneck_output = self.conv1(self.relu1(self.norm1(concated_features)))  # noqa: T484
#      50         return bottleneck_output
#      51
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     458
#     459     def forward(self, input: Tensor) -> Tensor:
# --> 460         return self._conv_forward(input, self.weight, self.bias)
#     461
#     462 class Conv3d(_ConvNd):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     454                             weight, bias, self.stride,
#     455                             _pair(0), self.dilation, self.groups)
# --> 456         return F.conv2d(input, weight, bias, self.stride,
#     457                         self.padding, self.dilation, self.groups)
#     458
#
# KeyboardInterrupt:

# %%
# /home/tomas/SYNC/BIO/EyeQ/MCF_Net/result/DenseNet121_v3_v1.csv
save_output_here(label_test_file, outPRED_mcs, save_file=save_file_name)
label_list = ['Good', 'Usable', 'Reject']
saver = SaveOutput(label_list)
saver.save(label_test_file, outPRED_mcs, save_file=save_file_name)

# %%
# evaluation:
df_gt = pd.read_csv(label_test_file)
img_list = df_gt["image"].tolist()
GT_QA_list = np.array(df_gt["quality"].tolist())
img_num = len(img_list)
label_list = ["Good", "Usable", "Reject"]

df_tmp = pd.read_csv(save_file_name)
predict_tmp = np.zeros([img_num, 3])
for idx in range(3):
    predict_tmp[:, idx] = np.array(df_tmp[label_list[idx]].tolist())
tmp_report = compute_metric(GT_QA_list, predict_tmp, target_names=label_list)

print(' Accuracy: ' + str("{:0.4f}".format(np.mean(tmp_report['Accuracy']))) +
      ' Precision: ' + str("{:0.4f}".format(np.mean(tmp_report['Precision']))) +
      ' Sensitivity: ' + str("{:0.4f}".format(np.mean(tmp_report['Sensitivity']))) +
      ' F1: ' + str("{:0.4f}".format(np.mean(tmp_report['F1']))))



calculator = MetricCalculator(GT_QA_list, predict_tmp, label_list)
calculator.get_metrics()

print(' Accuracy: ' + str("{:0.4f}".format(np.mean(calculator.metrics['Accuracy']))) +
      ' Precision: ' + str("{:0.4f}".format(np.mean(calculator.metrics['Precision']))) +
      ' Sensitivity: ' + str("{:0.4f}".format(np.mean(calculator.metrics['Sensitivity']))) +
      ' F1: ' + str("{:0.4f}".format(np.mean(calculator.metrics['F1']))))
# Out:
#  Accuracy: 0.9720 Precision: 0.9560 Sensitivity: 0.9570 F1: 0.9565
#  Accuracy: 0.9720 Precision: 0.9560 Sensitivity: 0.9570 F1: 0.9565

# %%
tmp_report
# Out:
# {'class_name': ['Good', 'Usable', 'Reject'],
#  'F1': array([[0.98567747],
#         [0.91285866],
#         [0.97087379]]),
#  'AUC': 0.9823343797523513,
#  'Accuracy': 0.9720162640516623,
#  'Sensitivity': array([[0.98526417],
#         [0.91577825],
#         [0.96982759]]),
#  'Precision': array([[0.98609113],
#         [0.90995763],
#         [0.97192225]]),
#  'Specificity': array([[0.97235462],
#         [0.984063  ],
#         [0.99364179]]),
#  'ROC_curve': {'ROC_fpr_0': array([0.        , 0.00142993, 0.00405148, ..., 0.98021926, 0.98021926,
#          1.        ]),
#   'ROC_tpr_0': array([0.        , 0.16808434, 0.26404696, ..., 0.9998802 , 1.        ,
#          1.        ]),
#   'ROC_T_0': array([       inf, 0.98759127, 0.98759115, ..., 0.02327108, 0.02323476,
#          0.01851259]),
#   'AUC_0': 0.9881430916595163,
#   'ROC_fpr_1': array([0.        , 0.        , 0.        , ..., 0.99896878, 0.99896878,
#          1.        ]),
#   'ROC_tpr_1': array([0.00000000e+00, 5.33049041e-04, 7.99573561e-03, ...,
#          9.99466951e-01, 1.00000000e+00, 1.00000000e+00]),
#   'ROC_T_1': array([       inf, 0.9506565 , 0.95045084, ..., 0.00723532, 0.00719809,
#          0.00367134]),
#   'AUC_1': 0.9623561787015052,
#   'ROC_fpr_2': array([0.        , 0.        , 0.        , ..., 0.96625257, 0.96644821,
#          1.        ]),
#   'ROC_tpr_2': array([0.00000000e+00, 4.31034483e-04, 2.58620690e-03, ...,
#          1.00000000e+00, 1.00000000e+00, 1.00000000e+00]),
#   'ROC_T_2': array([       inf, 0.9544151 , 0.9544135 , ..., 0.00823871, 0.00823865,
#          0.00525178]),
#   'AUC_2': 0.9965038688960324},
#  'tp': array([[8224.],
#         [1718.],
#         [2250.]]),
#  'tn': array([[ 4080.],
#         [10497.],
#         [10158.]]),
#  'fp': array([[116.],
#         [170.],
#         [ 65.]]),
#  'fn': array([[123.],
#         [158.],
#         [ 70.]]),
#  'micro-Precision': array([0.97201626]),
#  'micro-Sensitivity': array([0.97201626]),
#  'micro-Specificity': array([0.98600813]),
#  'micro-F1': array([0.97201626])}

# %%
data_train = DatasetGenerator(data_dir=train_images_dir, list_file=label_test_file, transform1=transform_list1, # label_train_file swapped with label_test_file
                              transform2=transformList2, n_class=n_classes, set_name='train')
train_loader = torch.utils.data.DataLoader(dataset=data_train, batch_size=batch_size,
                                               shuffle=True, num_workers=4, pin_memory=True)

# %%
data_val = DatasetGenerator(data_dir=train_images_dir, list_file=label_test_file, transform1=transform_list_val1,
                            transform2=transformList2, n_class=n_classes, set_name='val')
val_loader = torch.utils.data.DataLoader(dataset=data_val, batch_size=batch_size,
                                             shuffle=False, num_workers=4, pin_memory=True)

# %%
len(train_loader)
# get only 100 images for training
train_loader.dataset.image_names = train_loader.dataset.image_names[:100]
train_loader.dataset.labels = train_loader.dataset.labels[:100]

val_loader.dataset.image_names = val_loader.dataset.image_names[:100]
val_loader.dataset.labels = val_loader.dataset.labels[:100]
print('Train loader length: ', len(train_loader.dataset.image_names))
print('Train loader length: ', len(train_loader.dataset.labels))
print('Val loader length: ', len(val_loader.dataset.image_names))
print('Val loader length: ', len(val_loader.dataset.labels))
len(train_loader)
# Out:
# Train loader length:  100
# Train loader length:  100
# Val loader length:  100
# Val loader length:  100
# 25

# %% [markdown]
# nejde validation, asi by to chcelo ist mimo loopu a postupne krokovat jednotlive kroky kedze validation je jedna velka zahada a neviem ako to funguje
#
# + jebly torch po sebe ale necistil pamet, takze to padalo na cuda out of memory, tak som musel restartovat kernel... tak tebe jebe copilot to proste vyriesil za mna ez

# %%
epochs = 20
loss_w = [0.1, 0.1, 0.1, 0.1, 0.6]
_ = train_step_here(train_loader, model, 0, optimizer, criterion)
# Out:
# iters_per_epoch:  25
# Processing train Epoch -> 1 / 20 |################################| 25 / 25 | Time: 0.00 mins | Loss: 0.0450

# %%
epochs = 20
loss_w = [0.1, 0.1, 0.1, 0.1, 0.6]
trainer = Trainer(model, optimizer, criterion, loss_w, epochs)

# %%
trainer.train_step(train_loader, 0)
# Out:
# iters_per_epoch:  25
# Processing train Epoch -> 1 / 20 |################################| 25 / 25 | Time: 0.00 mins | Loss: 0.0530
# 0.12453977305442095

# %%
train_loader.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2136/2892884849.py in <module>
# ----> 1 train_loader.shape
#
# AttributeError: 'DataLoader' object has no attribute 'shape'

# %%
# free all GPU memory:
torch.cuda.empty_cache()

# free all GPU memory different way then above:
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
#val loader has only 3 values for each image, check if it is correct
(imagesA, imagesB, imagesC, labels) = val_loader.dataset.__getitem__(0)
print(imagesA.shape)
print(imagesB.shape)
print(imagesC.shape)
print(labels.shape)
# Out:
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([1, 3])

# %%
(imagesAa, imagesBa, imagesCa) = val_loader.dataset.__getitem__(0)
print(imagesAa.shape)
print(imagesBa.shape)
print(imagesCa.shape)
# get label for image 0
print(val_loader.dataset.labels[0].shape)
model.eval()
imagesAa = imagesAa.cuda()
imagesBa = imagesBa.cuda()
imagesCa = imagesCa.cuda()
labels = val_loader.dataset.labels[0]
# change from numpy to tensor
labels = torch.from_numpy(labels).float()
labels = labels.cuda()
labels = labels.squeeze(1)

_, _, _, _, outputs = model(imagesAa, imagesBa, imagesCa)
with torch.no_grad():
    loss = criterion(outputs, labels)
    print(loss.item())
    # epoch_loss += loss.item()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7011/2480430215.py in <module>
# ----> 1 (imagesAa, imagesBa, imagesCa) = val_loader.dataset.__getitem__(0)
#       2 print(imagesAa.shape)
#       3 print(imagesBa.shape)
#       4 print(imagesCa.shape)
#       5 # get label for image 0
#
# ValueError: too many values to unpack (expected 3)

# %%
epochs = 20
loss_w = [0.1, 0.1, 0.1, 0.1, 0.6]
# Train and val
for epoch in range(0, epochs):
    _ = train_step_here(train_loader, model, epoch, optimizer, criterion)
    validation_loss = validation_step_here(val_loader, model, criterion)
    print('Current Loss: {}| Best Loss: {} at epoch: {}'.format(validation_loss, best_metric, best_iter))

    # save model
    if best_metric > validation_loss:
        best_metric = validation_loss
        best_iter = epoch
        # model_save_file = os.path.join(args.save_dir, save_model + '.tar')
        # if not os.path.exists(save_dir):
        #     os.makedirs(save_dir)
        # torch.save({'state_dict': model.state_dict(), 'best_loss': best_metric}, model_save_file)
        # print('Model saved to %s' % model_save_file)
# Out:
# iters_per_epoch:  25
# Processing train Epoch -> 1 / 20 |################################| 25 / 25 | Time: 0.00 mins | Loss: 0.0517
# Current Loss: 0.033236809745430945| Best Loss: 0.024055843874812126 at epoch: 15
#
#
# iters_per_epoch:  25
# Processing train Epoch -> 2 / 20 |################################| 25 / 25 | Time: 0.00 mins | Loss: 0.0306
# Current Loss: 0.029031456187367438| Best Loss: 0.024055843874812126 at epoch: 15
#
#
# iters_per_epoch:  25
# Processing train Epoch -> 3 / 20 |#                               | 1 / 25 | Time: 0.08 mins | Loss: 0.0244
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7011/3540658393.py in <module>
#       3 # Train and val
#       4 for epoch in range(0, epochs):
# ----> 5     _ = train_step_here(train_loader, model, epoch, optimizer, criterion)
#       6     validation_loss = validation_step_here(val_loader, model, criterion)
#       7     print('Current Loss: {}| Best Loss: {} at epoch: {}'.format(validation_loss, best_metric, best_iter))
#
# /tmp/ipykernel_7011/2200030228.py in train_step_here(train_loader, model, epoch, optimizer, criterion)
#      24         labels = labels.squeeze(1)
#      25
# ---> 26         out_A, out_B, out_C, out_F, combine = model(imagesA, imagesB, imagesC)
#      27
#      28         loss_x = criterion(out_A, labels)
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/Nextcloud/SYNC/BIO/EyeQ/MCF_Net/networks/densenet_mcf.py in forward(self, x, y, z)
#      69         x2 = F.relu(x2, inplace=True)
#      70         x2 = F.adaptive_avg_pool2d(x2, (1, 1)).view(x2.size(0), -1)
# ---> 71         y2 = self.classB(y)
#      72         y2 = F.relu(y2, inplace=True)
#      73         y2 = F.adaptive_avg_pool2d(y2, (1, 1)).view(y2.size(0), -1)
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py in forward(self, input)
#     213     def forward(self, input):
#     214         for module in self:
# --> 215             input = module(input)
#     216         return input
#     217
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/.local/lib/python3.10/site-packages/torchvision/models/densenet.py in forward(self, init_features)
#     120         features = [init_features]
#     121         for name, layer in self.items():
# --> 122             new_features = layer(features)
#     123             features.append(new_features)
#     124         return torch.cat(features, 1)
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/.local/lib/python3.10/site-packages/torchvision/models/densenet.py in forward(self, input)
#      86             bottleneck_output = self.call_checkpoint_bottleneck(prev_features)
#      87         else:
# ---> 88             bottleneck_output = self.bn_function(prev_features)
#      89
#      90         new_features = self.conv2(self.relu2(self.norm2(bottleneck_output)))
#
# ~/.local/lib/python3.10/site-packages/torchvision/models/densenet.py in bn_function(self, inputs)
#      47     def bn_function(self, inputs: List[Tensor]) -> Tensor:
#      48         concated_features = torch.cat(inputs, 1)
# ---> 49         bottleneck_output = self.conv1(self.relu1(self.norm1(concated_features)))  # noqa: T484
#      50         return bottleneck_output
#      51
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/.local/lib/python3.10/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     169         used for normalization (i.e. in eval mode when buffers are not None).
#     170         """
# --> 171         return F.batch_norm(
#     172             input,
#     173             # If buffers are not to be tracked, ensure that they won't be updated
#
# ~/.local/lib/python3.10/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2476         _verify_batch_size(input.size())
#    2477
# -> 2478     return torch.batch_norm(
#    2479         input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2480     )
#
# KeyboardInterrupt:

# %%
validation_loss = validation_step_here(val_loader, model, criterion)

# %%
validation_loss
# Out:
# 0.05574897188693285

# %%
# Out:
# BCELoss()

# %%
def train_step_here(train_loader, model, epoch, optimizer, criterion):
    
    # switch to train mode
    model.train()
    epoch_loss = 0.0
    loss_w = [0.1, 0.1, 0.1, 0.1, 0.6]

    iters_per_epoch = len(train_loader)
    print('\n\niters_per_epoch: ', iters_per_epoch, '\n\n')
    bar = Bar('Processing {} Epoch -> {} / {}'.format('train', epoch+1, epochs), max=iters_per_epoch)
    bar.check_tty = False

    for step, (imagesA, imagesB, imagesC, labels) in enumerate(train_loader):
        start_time = time.time()

        torch.set_grad_enabled(True)

        imagesA = imagesA.cuda()
        imagesB = imagesB.cuda()
        imagesC = imagesC.cuda()

        labels = labels.cuda()
        # change the labels from shape [4,1,3] to [4,3]
        labels = labels.squeeze(1)

        out_A, out_B, out_C, out_F, combine = model(imagesA, imagesB, imagesC)

        loss_x = criterion(out_A, labels)
        loss_y = criterion(out_B, labels)
        loss_z = criterion(out_C, labels)
        loss_c = criterion(out_F, labels)
        loss_f = criterion(combine, labels)

        lossValue = loss_w[0]*loss_x+loss_w[1]*loss_y+loss_w[2]*loss_z+loss_w[3]*loss_c+loss_w[4]*loss_f


        optimizer.zero_grad()
        lossValue.backward()
        optimizer.step()

        # measure elapsed time
        epoch_loss += lossValue.item()
        end_time = time.time()
        batch_time = end_time - start_time
        # plot progress
        bar_str = '{} / {} | Time: {batch_time:.2f} mins | Loss: {loss:.4f} '
        bar.suffix = bar_str.format(step+1, iters_per_epoch, batch_time=batch_time*(iters_per_epoch-step)/60,
                                    loss=lossValue.item())
        bar.next()

    epoch_loss = epoch_loss / iters_per_epoch

    bar.finish()
    return epoch_loss

# %%
def validation_step_here(val_loader, model, criterion):

    # switch to train mode
    model.eval()
    epoch_loss = 0
    iters_per_epoch = len(val_loader)
    bar = Bar('Processing {}'.format('validation'), max=iters_per_epoch)

    for step, (imagesA, imagesB, imagesC, labels) in enumerate(val_loader):
        start_time = time.time()

        imagesA = imagesA.cuda()
        imagesB = imagesB.cuda()
        imagesC = imagesC.cuda()

        labels = labels.cuda()
        labels = labels.squeeze(1)

        _, _, _, _, outputs = model(imagesA, imagesB, imagesC)
        with torch.no_grad():
            loss = criterion(outputs, labels)
            epoch_loss += loss.item()

        end_time = time.time()

        # measure elapsed time
        batch_time = end_time - start_time
        bar_str = '{} / {} | Time: {batch_time:.2f} mins'
        bar.suffix = bar_str.format(step + 1, len(val_loader), batch_time=batch_time * (iters_per_epoch - step) / 60)
        bar.next()

    epoch_loss = epoch_loss / iters_per_epoch
    bar.finish()
    return epoch_loss

# %% [markdown]
# validation

# %%
validator = Validator(model, criterion)
validation_loss = validator.validate(val_loader)
validation_loss
# Out:
# 0.05574897188693285
